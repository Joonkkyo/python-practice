# %% [markdown]
# # 데이터 정제 및 준비

# %%
import numpy as np
import pandas as pd
PREVIOUS_MAX_ROWS = pd.options.display.max_rows
pd.options.display.max_rows = 20
np.random.seed(12345)
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(10, 6))
np.set_printoptions(precision=4, suppress=True)

# %% [markdown]
# ## 누락 데이터 처리하기

# %%
string_data = pd.Series(['aardvark', 'artichoke', np.nan, 'avocado'])
string_data
string_data.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
string_data[0] = None
string_data.isnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %% [markdown]
# ### 누락 데이터 골라내기 : dropna()

# %%
from numpy import nan as NA
data = pd.Series([1, NA, 3.5, NA, 7])
data.dropna()
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data[data.notnull()]
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data = pd.DataFrame([[1., 6.5, 3.], [1., NA, NA],
                     [NA, NA, NA], [NA, 6.5, 3.]])
cleaned = data.dropna()

# %%
data
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
cleaned
# Out:
#      0    1    2
# 0  1.0  6.5  3.0

# %%
data.dropna(how='all')
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data[4] = NA
data
# Out:
#      0    1    2   4
# 0  1.0  6.5  3.0 NaN
# 1  1.0  NaN  NaN NaN
# 2  NaN  NaN  NaN NaN
# 3  NaN  6.5  3.0 NaN

# %%
data.dropna(axis=1, how='all')

# %%
df = pd.DataFrame(np.random.randn(7, 3))
df.iloc[:4, 1] = NA
df.iloc[:2, 2] = NA
df

# %%
df.dropna()

# %%
# 몇 개의 이상값이 들어있는 로우만 볼 경우
df.dropna(thresh=2)

# %% [markdown]
# ### 결측치 채우기: fillna()

# %%
df.fillna(0)

# %%
df.fillna({1: 0.5, 2: 0})

# %%
df.fillna(df.mean())

# %% [markdown]
# ## 데이터 변형

# %% [markdown]
# ### 중복 제거: drop_duplicates()

# %%
data = pd.DataFrame({'k1': ['one', 'two'] * 3 + ['two'],
                     'k2': [1, 1, 2, 3, 3, 4, 4]})
data

# %%
data.duplicated()

# %%
data.drop_duplicates()

# %%
data['v1'] = range(7)
#k1 컬럼에 기반해서 중복 제거
data.drop_duplicates(['k1'])

# %%
# 중복값 중, 마지막으로 발견된 값을 유지
data.drop_duplicates(['k1', 'k2'], keep='last')

# %% [markdown]
# ### 함수나 매핑을 이용해서 데이터 변형하기 : map()

# %%
data = pd.DataFrame({'food': ['bacon', 'pulled pork', 'bacon',
                              'Pastrami', 'corned beef', 'Bacon',
                              'pastrami', 'honey ham', 'nova lox'],
                     'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     Pastrami     6.0
# 4  corned beef     7.5
# 5        Bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
meat_to_animal = {
  'bacon': 'pig',
  'pulled pork': 'pig',
  'pastrami': 'cow',
  'corned beef': 'cow',
  'honey ham': 'pig',
  'nova lox': 'salmon'
}

# %%
data['animal'] = data['food'].str.lower().map(meat_to_animal)
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     Pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        Bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
data['food'].map(lambda x: meat_to_animal[x.lower()])
# Out:
# 0       pig
# 1       pig
# 2       pig
# 3       cow
# 4       cow
# 5       pig
# 6       cow
# 7       pig
# 8    salmon
# Name: food, dtype: object

# %% [markdown]
# ### 값 치환하기 : replace()

# %%
data = pd.Series([1., -999., 2., -999., -1000., 3.])
data
# Out:
# 0       1.0
# 1    -999.0
# 2       2.0
# 3    -999.0
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace(-999, np.nan)
# Out:
# 0       1.0
# 1       NaN
# 2       2.0
# 3       NaN
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace([-999, -1000], np.nan)
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    NaN
# 5    3.0
# dtype: float64

# %%
data.replace([-999, -1000], [np.nan, 0])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    0.0
# 5    3.0
# dtype: float64

# %%
data.replace({-999: np.nan, -1000: 0})

# %% [markdown]
# ### 컬럼/색인 이름 바꾸기: rename

# %%
data = pd.DataFrame(np.arange(12).reshape((3, 4)),
                    index=['Ohio', 'Colorado', 'New York'],
                    columns=['one', 'two', 'three', 'four'])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York    8    9     10    11

# %%
transform = lambda x: x[:4].upper()
data.index.map(transform)
# Out:
# Index(['OHIO', 'COLO', 'NEW '], dtype='object')

# %%
data.index = data.index.map(transform)
data
# Out:
#       one  two  three  four
# OHIO    0    1      2     3
# COLO    4    5      6     7
# NEW     8    9     10    11

# %%
data.rename(index=str.title, columns=str.upper)
# Out:
#       ONE  TWO  THREE  FOUR
# Ohio    0    1      2     3
# Colo    4    5      6     7
# New     8    9     10    11

# %%
data.rename(index={'OHIO': 'INDIANA'},
            columns={'three': 'peekaboo'})
# Out:
#          one  two  peekaboo  four
# INDIANA    0    1         2     3
# COLO       4    5         6     7
# NEW        8    9        10    11

# %%
data.rename(index={'OHIO': 'INDIANA'}, inplace=True)
data
# Out:
#          one  two  three  four
# INDIANA    0    1      2     3
# COLO       4    5      6     7
# NEW        8    9     10    11

# %% [markdown]
# ### 개별화(Discretization) and 양자화(Binning)

# %%
ages = [20, 22, 25, 27, 21, 23, 37, 31, 61, 45, 41, 32]

# %%
bins = [18, 25, 35, 60, 100]
cats = pd.cut(ages, bins)
cats
# Out:
# [(18, 25], (18, 25], (18, 25], (25, 35], (18, 25], ..., (25, 35], (60, 100], (35, 60], (35, 60], (25, 35]]
# Length: 12
# Categories (4, interval[int64]): [(18, 25] < (25, 35] < (35, 60] < (60, 100]]

# %%
cats.codes
# Out:
# array([0, 0, 0, 1, 0, 0, 2, 1, 3, 2, 2, 1], dtype=int8)

# %%
cats.categories
# Out:
# IntervalIndex([(18, 25], (25, 35], (35, 60], (60, 100]],
#               closed='right',
#               dtype='interval[int64]')

# %%
pd.value_counts(cats)
# Out:
# (18, 25]     5
# (35, 60]     3
# (25, 35]     3
# (60, 100]    1
# dtype: int64

# %%
pd.cut(ages, [18, 26, 36, 61, 100], right=False)
# Out:
# [[18, 26), [18, 26), [18, 26), [26, 36), [18, 26), ..., [26, 36), [61, 100), [36, 61), [36, 61), [26, 36)]
# Length: 12
# Categories (4, interval[int64]): [[18, 26) < [26, 36) < [36, 61) < [61, 100)]

# %%
group_names = ['Youth', 'YoungAdult', 'MiddleAged', 'Senior']
pd.cut(ages, bins, labels=group_names)
# Out:
# [Youth, Youth, Youth, YoungAdult, Youth, ..., YoungAdult, Senior, MiddleAged, MiddleAged, YoungAdult]
# Length: 12
# Categories (4, object): [Youth < YoungAdult < MiddleAged < Senior]

# %% [markdown]
# ### 특잇값 찾고 제외하기

# %%
data = pd.DataFrame(np.random.randn(1000, 4))
data
# Out:
#             0         1         2         3
# 0   -0.204708  0.478943 -0.519439 -0.555730
# 1    1.965781  1.393406  0.092908  0.281746
# 2    0.769023  1.246435  1.007189 -1.296221
# 3    0.274992  0.228913  1.352917  0.886429
# 4   -2.001637 -0.371843  1.669025 -0.438570
# ..        ...       ...       ...       ...
# 995  1.089085  0.251232 -1.451985  1.653126
# 996 -0.478509 -0.010663 -1.060881 -1.502870
# 997 -1.946267  1.013592  0.037333  0.133304
# 998 -1.293122 -0.322542 -0.782960 -0.303340
# 999  0.089987  0.292291  1.177706  0.882755
#
# [1000 rows x 4 columns]

# %%
data.describe()
# Out:
#                  0            1            2            3
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -0.067684     0.067924     0.025598    -0.002298
# std       0.998035     0.992106     1.006835     0.996794
# min      -3.428254    -3.548824    -3.184377    -3.745356
# 25%      -0.774890    -0.591841    -0.641675    -0.644144
# 50%      -0.116401     0.101143     0.002073    -0.013611
# 75%       0.616366     0.780282     0.680391     0.654328
# max       3.366626     2.653656     3.260383     3.927528

# %%
col = data[2]
col[np.abs(col) > 3]
# Out:
# 5      3.248944
# 102    3.176873
# 324    3.260383
# 499   -3.056990
# 586   -3.184377
# Name: 2, dtype: float64

# %%
# 절대값이 3을 초과하는 값이 들어있는 모든 로우 선택
data[(np.abs(data) > 3).any(1)]
# Out:
#             0         1         2         3
# 5   -0.539741  0.476985  3.248944 -1.021228
# 97  -0.774363  0.552936  0.106061  3.927528
# 102 -0.655054 -0.565230  3.176873  0.959533
# 305 -2.315555  0.457246 -0.025907 -3.399312
# 324  0.050188  1.951312  3.260383  0.963301
# 400  0.146326  0.508391 -0.196713 -3.745356
# 499 -0.293333 -0.242459 -3.056990  1.918403
# 523 -3.428254 -0.296336 -0.439938 -0.867165
# 586  0.275144  1.179227 -3.184377  1.369891
# 808 -0.362528 -3.548824  1.553205 -2.186301
# 900  3.366626 -2.372214  0.851010  1.332846

# %%
# 절대값이 3을 초과하는 수는 3 또는 -3으로 설정
# sign(data) : 양수(1) or 음수(-1)인지 판단
data[np.abs(data) > 3] = np.sign(data) * 3
data.describe()
# Out:
#                  0            1            2            3
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -0.067623     0.068473     0.025153    -0.002081
# std       0.995485     0.990253     1.003977     0.989736
# min      -3.000000    -3.000000    -3.000000    -3.000000
# 25%      -0.774890    -0.591841    -0.641675    -0.644144
# 50%      -0.116401     0.101143     0.002073    -0.013611
# 75%       0.616366     0.780282     0.680391     0.654328
# max       3.000000     2.653656     3.000000     3.000000

# %% [markdown]
# ## 연습문제
#
# - 자유롭게 데이터전처리하기
#
#     [예시]
#     - 컬럼명 변경하기
#     - 날짜 데이터 파싱하기
#     - 이상치 처리하기
#     - 계절, 날씨를 text로 변경하기(예: 봄, 여름, 가을, 겨울)
#     - 자전거 대여횟수를 카테고리화 하기(예: 매우 적음, 적음, 보통, 많음, 매우 많음)
#     - atemp 값을 소수점 2자리까지 보여지도록 바꾸기
#
#
# - 데이터전처리 과정을 마친 데이터프레임을 csv 형태로 저장
#
# - 코드제출
#
#     https://drive.google.com/drive/folders/149Ryp8xzvMnklI4bY7kF074tSsr5-H0c?usp=sharing

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# 읽어드릴 파일 경로 : /dataset/bike_sharing_demand_train.csv
filepath = "bike_sharing_demand_train.csv"
df = pd.read_csv(filepath)
df
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 0      14.395        81     0.0000       3          13     16
# 1      13.635        80     0.0000       8          32     40
# 2      13.635        80     0.0000       5          27     32
# 3      14.395        75     0.0000       3          10     13
# 4      14.395        75     0.0000       0           1      1
# ...       ...       ...        ...     ...         ...    ...
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88
#
# [10886 rows x 12 columns]

# %%
df = df.rename(columns={'datetime': 'date'})
df
# Out:
#                       date  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 0      14.395        81     0.0000       3          13     16
# 1      13.635        80     0.0000       8          32     40
# 2      13.635        80     0.0000       5          27     32
# 3      14.395        75     0.0000       3          10     13
# 4      14.395        75     0.0000       0           1      1
# ...       ...       ...        ...     ...         ...    ...
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88
#
# [10886 rows x 12 columns]

# %%
df_1 = df['season'].replace([1, 2, 3, 4], ['봄', '여름', '가을', '겨울'])
df['season'] = df_1
df
# Out:
#                       date season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00      봄        0           0        1   9.84
# 1      2011-01-01 01:00:00      봄        0           0        1   9.02
# 2      2011-01-01 02:00:00      봄        0           0        1   9.02
# 3      2011-01-01 03:00:00      봄        0           0        1   9.84
# 4      2011-01-01 04:00:00      봄        0           0        1   9.84
# ...                    ...    ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00     겨울        0           1        1  15.58
# 10882  2012-12-19 20:00:00     겨울        0           1        1  14.76
# 10883  2012-12-19 21:00:00     겨울        0           1        1  13.94
# 10884  2012-12-19 22:00:00     겨울        0           1        1  13.94
# 10885  2012-12-19 23:00:00     겨울        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 0      14.395        81     0.0000       3          13     16
# 1      13.635        80     0.0000       8          32     40
# 2      13.635        80     0.0000       5          27     32
# 3      14.395        75     0.0000       3          10     13
# 4      14.395        75     0.0000       0           1      1
# ...       ...       ...        ...     ...         ...    ...
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88
#
# [10886 rows x 12 columns]

# %%
df = df.dropna()
df
# Out:
#                       date season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00      봄        0           0        1   9.84
# 1      2011-01-01 01:00:00      봄        0           0        1   9.02
# 2      2011-01-01 02:00:00      봄        0           0        1   9.02
# 3      2011-01-01 03:00:00      봄        0           0        1   9.84
# 4      2011-01-01 04:00:00      봄        0           0        1   9.84
# ...                    ...    ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00     겨울        0           1        1  15.58
# 10882  2012-12-19 20:00:00     겨울        0           1        1  14.76
# 10883  2012-12-19 21:00:00     겨울        0           1        1  13.94
# 10884  2012-12-19 22:00:00     겨울        0           1        1  13.94
# 10885  2012-12-19 23:00:00     겨울        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 0      14.395        81     0.0000       3          13     16
# 1      13.635        80     0.0000       8          32     40
# 2      13.635        80     0.0000       5          27     32
# 3      14.395        75     0.0000       3          10     13
# 4      14.395        75     0.0000       0           1      1
# ...       ...       ...        ...     ...         ...    ...
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88
#
# [10886 rows x 12 columns]

# %%
df[['count']].describe()
# Out:
#               count
# count  10886.000000
# mean     191.574132
# std      181.144454
# min        1.000000
# 25%       42.000000
# 50%      145.000000
# 75%      284.000000
# max      977.000000

# %%
f = lambda x : '%.2f' % x
df['atemp'] = df['atemp'].apply(f)
df
# Out:
#                       date season  holiday  workingday  weather   temp  atemp  \
# 0      2011-01-01 00:00:00      봄        0           0        1   9.84  14.39
# 1      2011-01-01 01:00:00      봄        0           0        1   9.02  13.63
# 2      2011-01-01 02:00:00      봄        0           0        1   9.02  13.63
# 3      2011-01-01 03:00:00      봄        0           0        1   9.84  14.39
# 4      2011-01-01 04:00:00      봄        0           0        1   9.84  14.39
# ...                    ...    ...      ...         ...      ...    ...    ...
# 10881  2012-12-19 19:00:00     겨울        0           1        1  15.58  19.70
# 10882  2012-12-19 20:00:00     겨울        0           1        1  14.76  17.43
# 10883  2012-12-19 21:00:00     겨울        0           1        1  13.94  15.91
# 10884  2012-12-19 22:00:00     겨울        0           1        1  13.94  17.43
# 10885  2012-12-19 23:00:00     겨울        0           1        1  13.12  16.66
#
#        humidity  windspeed  casual  registered  count
# 0            81     0.0000       3          13     16
# 1            80     0.0000       8          32     40
# 2            80     0.0000       5          27     32
# 3            75     0.0000       3          10     13
# 4            75     0.0000       0           1      1
# ...         ...        ...     ...         ...    ...
# 10881        50    26.0027       7         329    336
# 10882        57    15.0013      10         231    241
# 10883        61    15.0013       4         164    168
# 10884        61     6.0032      12         117    129
# 10885        66     8.9981       4          84     88
#
# [10886 rows x 12 columns]

# %%
df['degree'] = pd.cut(df['count'], bins = [0, 20, 60, 150, 284, 978], 
                      labels=['매우 적음', '적음', '보통', '많음', '매우 많음'])
df
# Out:
#                       date season  holiday  workingday  weather   temp  atemp  \
# 0      2011-01-01 00:00:00      봄        0           0        1   9.84  14.39
# 1      2011-01-01 01:00:00      봄        0           0        1   9.02  13.63
# 2      2011-01-01 02:00:00      봄        0           0        1   9.02  13.63
# 3      2011-01-01 03:00:00      봄        0           0        1   9.84  14.39
# 4      2011-01-01 04:00:00      봄        0           0        1   9.84  14.39
# ...                    ...    ...      ...         ...      ...    ...    ...
# 10881  2012-12-19 19:00:00     겨울        0           1        1  15.58  19.70
# 10882  2012-12-19 20:00:00     겨울        0           1        1  14.76  17.43
# 10883  2012-12-19 21:00:00     겨울        0           1        1  13.94  15.91
# 10884  2012-12-19 22:00:00     겨울        0           1        1  13.94  17.43
# 10885  2012-12-19 23:00:00     겨울        0           1        1  13.12  16.66
#
#        humidity  windspeed  casual  registered  count degree
# 0            81     0.0000       3          13     16  매우 적음
# 1            80     0.0000       8          32     40     적음
# 2            80     0.0000       5          27     32     적음
# 3            75     0.0000       3          10     13  매우 적음
# 4            75     0.0000       0           1      1  매우 적음
# ...         ...        ...     ...         ...    ...    ...
# 10881        50    26.0027       7         329    336  매우 많음
# 10882        57    15.0013      10         231    241     많음
# 10883        61    15.0013       4         164    168     많음
# 10884        61     6.0032      12         117    129     보통
# 10885        66     8.9981       4          84     88     보통
#
# [10886 rows x 13 columns]

# %%
df.to_csv('bicycle_서준교.csv', encoding='utf-8-sig')
